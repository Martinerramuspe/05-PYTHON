# %%
def duplicar_elementos(lista):
    return [elemento * 2 for elemento in lista]

# %%
n= [1,42,2,3,1,5,4]
d= [2,1,4,2,1,1,1,2,3]
g= [3,2,4,41,1,5,5,5,3]

# %%
duplicar_elementos(n)
# Out:
# [2, 84, 4, 6, 2, 10, 8]

# %%
duplicar_elementos(g)
# Out:
# [6, 4, 8, 82, 2, 10, 10, 10, 6]

# %%
def algoritmo(x):
  return (43*4+ x)

# %%
for celda in columna:
  algoritmo(x)

# %%
# PRIMERA forma de aplicarle una funcion a cada una de las celdas de una columna correspondiente a un dataframe. ES MAS ELEGANTE.
import pandas as pd
def algoritmo(x):
    return 4 + x

data = {'columna': [1, 2, 3, 4, 5]}
df = pd.DataFrame(data)

df['columna'].apply(algoritmo)
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# 4    9
# Name: columna, dtype: int64

# %%
# SEGUNDA  forma de aplicarle una funcion a cada una de las celdas de una columna correspondiente a un dataframe. ES MAS ROBUSTA.
import pandas as pd
def algoritmo(x):
    return  4 + x

data = {'columna': [1, 2, 3, 4, 5]}
df = pd.DataFrame(data)

for x in df['columna']:
   print (algoritmo(x))
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
import re

# Definir la expresión regular
patron = re.compile(r'\b\w+\b')

# Buscar coincidencias en una cadena
cadena = "Esto es un ejemplo de expresiones regulares en Python."
resultados = patron.findall(cadena)

# Imprimir los resultados
print(resultados)
# Out:
# ['Esto', 'es', 'un', 'ejemplo', 'de', 'expresiones', 'regulares', 'en', 'Python']
